# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Mall_Customers.csv')
df.reset_index(drop=True, inplace=True)
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# Changing last two column names for easier analysis
df.rename(index=str, columns={'Annual Income (k$)': 'AnnualIncome',
                              'Spending Score (1-100)': 'Score',
                              'Genre': 'Gender'}, inplace=True)
df.head()
# Out:
#    CustomerID  Gender  Age  AnnualIncome  Score
# 0           1    Male   19            15     39
# 1           2    Male   21            15     81
# 2           3  Female   20            16      6
# 3           4  Female   23            16     77
# 4           5  Female   31            17     40

# %%
import seaborn as sns

# %% [markdown]
# * Lets visualize the distrubution of our features by gender using sns.
# * for that we will have to drop CustomerID as it is not relevant to our distrubtion at this this.

# %%
df_noID = df.drop(['CustomerID'], axis = 1)
df_noGender = df.drop(['Gender'], axis = 1)

# %%
sns.pairplot(data=df_noID, hue='Gender')

# %% [markdown]
# * Lets make a correlation heatmap for the features

# %%
mask = np.triu(np.ones_like(df[['Gender','Age','AnnualIncome','Score']].corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %%
sns.heatmap(df_noID[['Gender','Age','AnnualIncome','Score']].corr(), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Histograms for the all features

# %%
for i in df_noID.columns:
    col_num = df_noID[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(col_num)))
    chart = sns.barplot(x=col_num.index, y=col_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Gender: total = 2
# graph for Age: total = 20
# graph for AnnualIncome: total = 20
# graph for Score: total = 20

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler # Visualizing the elbow for number of clusters

# %%
clusters  = []

# %%
mms = MinMaxScaler()
mms.fit(df_noGender)
df_noGender_transformed = mms.transform(df_noGender)

Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(df_noGender_transformed)
    Sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# C:\Users\Sheryar Kahout\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# * It appears that nclusters = 5 would be good enough however we can also make a valid case for nclusters = 3.
# * I will do both to compore the results visually.

# %% [markdown]
# * Kmeans with n_clusters = 3

# %%
kmeans3 = KMeans(n_clusters=3, random_state = 0).fit(df_noGender)

df_noGender['Clusters'] = kmeans3.labels_

#lets visualize our plot
plt.figure(figsize=(12, 8))
sns.scatterplot(df_noGender['AnnualIncome'], df_noGender['Score'], hue=df_noGender['Clusters'], 
                palette=sns.color_palette('hls', 3))
plt.title('KMeans with 3 Clusters')
plt.show()
# Out:
# C:\Users\Sheryar Kahout\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Kmeans with nclusters = 5

# %%
kmeans5 = KMeans(n_clusters=5, random_state = 0).fit(df_noGender)

df_noGender['Clusters'] = kmeans5.labels_

#lets visualize our plot
plt.figure(figsize=(12, 8))
sns.scatterplot(df_noGender['AnnualIncome'], df_noGender['Score'], hue=df_noGender['Clusters'], 
                palette=sns.color_palette('hls', 5))
plt.title('KMeans with 5 Clusters')
plt.show()
# Out:
# C:\Users\Sheryar Kahout\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
